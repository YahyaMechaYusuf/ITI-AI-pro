# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder

# %%
top=pd.read_csv('Top_Scorers_dataset.csv' , sep = ',')
top.head()
# Out:
#    Rank           Name Nationality  Goals
# 0     1   Alan Shearer     England    260
# 1     2   Wayne Rooney     England    208
# 2     3    Andrew Cole     England    187
# 3     4  Sergio Agüero   Argentina    184
# 4     5  Frank Lampard     England    177

# %%
t_j=pd.read_json('players_stats.json')
t_j.head()
# Out:
#             Name  Height_cm  Appearances  Wins  Losses  Goals_per_match  \
# 0   Michael Owen        173          326   142      95             0.46
# 1  Jermain Defoe        171          496   185     188             0.33
# 2     Harry Kane        188          245   136      57             0.68
# 3  Mohamed Salah        175          158   107      21             0.61
# 4  Romelu Lukaku        190          252   112      80             0.45
#
#    Assists  Yellow_cards  Red_cards
# 0       31            10          1
# 1       33            40          2
# 2       34            27          0
# 3       34             4          0
# 4       35            19          0

# %%
new_f= pd.merge(top,t_j, how='inner', on='Name')

new_f
# Out:
#     Rank                     Name        Nationality  Goals  Height_cm  \
# 0      1             Alan Shearer            England    260        183
# 1      2             Wayne Rooney            England    208        176
# 2      3              Andrew Cole            England    187        178
# 3      4            Sergio Agüero          Argentina    184        173
# 4      5            Frank Lampard            England    177        184
# 5      6            Thierry Henry             France    175        188
# 6      7               Harry Kane            England    166        188
# 7      8            Robbie Fowler            England    163        173
# 8      9            Jermain Defoe            England    162        171
# 9     10             Michael Owen            England    150        173
# 10    11            Les Ferdinand            England    149        180
# 11    12         Teddy Sheringham            England    146        183
# ...

# %%
plt.scatter(new_f['Appearances'],new_f['Goals'])
plt.xlabel('Appearances')
plt.ylabel('Goals')
plt.title('Question 5')
# Out:
# Text(0.5, 1.0, 'Question 5')
